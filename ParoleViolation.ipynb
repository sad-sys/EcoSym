# %%
import matplotlib.pyplot as plt

def plot_isolate_counts_from_string(data_string):
    """
    Plot a bar graph from isolate data provided as a multiline string.

    :param data_string: A string containing isolate labels and their counts, separated by tabs.
    """
    # Splitting the string into lines and then into isolates and counts
    data = [line.split('\t') for line in data_string.strip().split('\n')]
    isolates, counts = zip(*[(isolate, int(count)) for isolate, count in data])

    # Creating the bar plot
    plt.figure(figsize=(10, 6))
    plt.bar(isolates, counts, color='skyblue')
    plt.xlabel('Isolate')
    plt.ylabel('Count')
    plt.title('MiSeq Isolate Counts')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    plt.show()

# Sample data string
sample_data_string = """
01-001	1074230
01-006	1160786
01-015	1178195
01-020	958518
01-035	560084
01-039	719406
01-044	441037
01-060	770743
01-074	285615
01-078	1249467
01-083	363799
02-012	493996
02-061	692824
02-084	893420
03-003	754028
03-008	1310210
03-018	501881
03-060	1420308
03-070	2102066
03-077	901805
03-089	1254552
04-040	740840
04-063	607046
04-078	628009
05-015	588750
05-072	724090
06-024	507046
06-088	2981300
07-072	508978
08-008	493539
08-038	432987
08-096	337113
09-010	305656
09-015	394712
09-049	1389692
09-060	322746
09-076	2182435
09-095	709544
10-051	4081400
10-069	450713
10-075	2607478
11-004	921581
11-011	553107
11-025	1999088
11-064	907723
12-023	834167
12-064	460061
12-078	389561
"""

# Plotting the sample data
plot_isolate_counts_from_string(sample_data_string)

# %%
import matplotlib.pyplot as plt

def plot_isolate_counts_from_string(data_string):
    """
    Plot a bar graph from isolate data provided as a multiline string.

    :param data_string: A string containing isolate labels and their counts, separated by tabs.
    """
    # Splitting the string into lines and then into isolates and counts
    data = [line.split('\t') for line in data_string.strip().split('\n')]
    isolates, counts = zip(*[(isolate, int(count)) for isolate, count in data])

    # Creating the bar plot
    plt.figure(figsize=(10, 6))
    plt.bar(isolates, counts, color='skyblue')
    plt.xlabel('Isolate')
    plt.ylabel('Count')
    plt.title('MinION Isolate Counts')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    plt.show()

# Sample data string
sample_data_string = """
01-001	1171965
01-006	261481
01-015	102038
01-020	94901
01-035	179097
01-044	832949
01-060	587068
01-074	170102
01-078	121981
01-083	55950
02-012	23952
02-061	109511
02-084	426333
03-003	91457
03-008	250112
03-018	442832
03-060	88259
03-070	128831
03-077	62600
03-089	198243
04-040	216000
04-063	164000
04-078	3227
05-015	208000
05-072	47333
06-024	133995
06-088	6095
07-072	58600
08-008	90453
08-038	47766
08-096	50266
09-010	308000
09-015	200000
09-049	72000
09-060	57602
09-076	135068
09-095	14559
10-051	73870
10-069	170341
10-075	68641
11-004	2722
11-011	17583
11-025	44000
11-064	102912
12-023	630477
12-064	123477
12-078	103381
"""

# Plotting the sample data
plot_isolate_counts_from_string(sample_data_string)

# %%
# Sample data strings for MiSeq and MinION
sample_data_string_miseq = """
01-001	1074230
01-006	1160786
01-015	1178195
01-020	958518
01-035	560084
01-039	719406
01-044	441037
01-060	770743
01-074	285615
01-078	1249467
01-083	363799
02-012	493996
02-061	692824
02-084	893420
03-003	754028
03-008	1310210
03-018	501881
03-060	1420308
03-070	2102066
03-077	901805
03-089	1254552
04-040	740840
04-063	607046
04-078	628009
05-015	588750
05-072	724090
06-024	507046
06-088	2981300
07-072	508978
08-008	493539
08-038	432987
08-096	337113
09-010	305656
09-015	394712
09-049	1389692
09-060	322746
09-076	2182435
09-095	709544
10-051	4081400
10-069	450713
10-075	2607478
11-004	921581
11-011	553107
11-025	1999088
11-064	907723
12-023	834167
12-064	460061
12-078	389561
"""

sample_data_string_minion = """
01-001	1171965
01-006	261481
01-015	102038
01-020	94901
01-035	179097
01-044	832949
01-060	587068
01-074	170102
01-078	121981
01-083	55950
02-012	23952
02-061	109511
02-084	426333
03-003	91457
03-008	250112
03-018	442832
03-060	88259
03-070	128831
03-077	62600
03-089	198243
04-040	216000
04-063	164000
04-078	3227
05-015	208000
05-072	47333
06-024	133995
06-088	6095
07-072	58600
08-008	90453
08-038	47766
08-096	50266
09-010	308000
09-015	200000
09-049	72000
09-060	57602
09-076	135068
09-095	14559
10-051	73870
10-069	170341
10-075	68641
11-004	2722
11-011	17583
11-025	44000
11-064	102912
12-023	630477
12-064	123477
12-078	103381
"""

# Function to parse the data string and find the maximum count value
def find_max_count(data_string):
    data = [line.split('\t') for line in data_string.strip().split('\n')]
    counts = [int(count) for _, count in data]
    return max(counts)

# Finding the maximum count value from both datasets
max_count_miseq = find_max_count(sample_data_string_miseq)
max_count_minion = find_max_count(sample_data_string_minion)
ymax = max(max_count_miseq, max_count_minion)

ymax

import matplotlib.pyplot as plt

def plot_isolate_counts_from_string(data_string, ymax, title):
    """
    Plot a bar graph from isolate data provided as a multiline string with a consistent y-axis limit.

    :param data_string: A string containing isolate labels and their counts, separated by tabs.
    :param ymax: Maximum value for the y-axis to ensure consistent scale across plots.
    :param title: Title for the plot.
    """
    # Splitting the string into lines and then into isolates and counts
    data = [line.split('\t') for line in data_string.strip().split('\n')]
    isolates, counts = zip(*[(isolate, int(count)) for isolate, count in data])

    # Creating the bar plot
    plt.figure(figsize=(10, 6))
    plt.bar(isolates, counts, color='skyblue')
    plt.xlabel('Isolate')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=45)
    plt.ylim(0, ymax)  # Setting the y-axis limit
    plt.tight_layout()

    # Display the plot
    plt.show()

# Plotting MiSeq data with consistent scale
plot_isolate_counts_from_string(sample_data_string_miseq, ymax, 'MiSeq Isolate Counts')

# Plotting MinION data with consistent scale
plot_isolate_counts_from_string(sample_data_string_minion, ymax, 'MinION Isolate Counts')

# %%
import matplotlib.pyplot as plt

# Data provided by the user
data = {
    'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
             2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'results': [4810, 8630, 9090, 12300, 46600, 79500, 99500, 116000, 128000, 132000,
                142000, 139000, 145000, 146000, 146000, 149000, 143000, 139000, 133000,
                116000, 103000, 83200, 63800, 45800]
}

# Creating a bar chart
plt.figure(figsize=(10, 6))
plt.bar(data['year'], data['results'], color='skyblue')
plt.title('Papers containing the term "Personalised Treatment" between 2000 and 2023')
plt.xlabel('Year')
plt.ylabel('Results')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
